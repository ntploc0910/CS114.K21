# %% [markdown]
# <a href="https://colab.research.google.com/github/tuananh11052000/CS114.K21/blob/master/DU_DOAN_THOI_GIAN_CHAY_CUA_CHUONG_TRINH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# import các thư viện cần thiết

# %%
import pandas as pd
import matplotlib.pyplot as plt
import random
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import numpy as np
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# Từ dữ liệu trên web, copy về và lưu dưới dạng file csv

# %% [markdown]
# Thực hiện load file từ local lên notebook

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fb1798fe-0475-4122-82f9-e7f933d0cefa" name="files[]" multiple disabled />
#      <output id="result-fb1798fe-0475-4122-82f9-e7f933d0cefa">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving dataset.csv to dataset.csv
# ...

# %% [markdown]
# Đọc dữ liệu

# %%
time_df = pd.read_csv('dataset.csv', names=["size", "time"])
size = time_df['size'].astype(float)
labels = pr_df['time'].values

# %% [markdown]
# Chia dữ liệu train-test 80-20

# %%
# split train-test set
X_train, X_test, y_train, y_test = train_test_split(data, labels, test_size=0.2, random_state=0)
print(X_test[:5])
# Out:
# [[2.66162600e+06 7.08425296e+12 5.68094165e+07]
#  [7.54827800e+06 5.69765008e+13 1.72460913e+08]
#  [2.31665100e+06 5.36687186e+12 4.89823636e+07]
#  [1.97702800e+06 3.90863971e+12 4.13493466e+07]
#  [6.33747800e+06 4.01636274e+13 1.43198341e+08]]

# %% [markdown]
# Chọn model và huấn luyện

# %%
# choose model Linearn Regression
lire = LinearRegression()
lire.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# Thực hiện dự đoán

# %%
# Predict time
y_pred = lire.predict([])
print('weight: ', lire.coef_)
print('bias: ',lire.intercept_)
# Out:
# weight:  [ 4.64869785e-09 -1.34867177e-17  3.40724362e-09]
# bias:  0.0002330963442465639

# %% [markdown]
# Đánh giá model

# %%
# Print test error
print('Mean squared error: %.2f' % mean_squared_error(y_test, y_pred))
# The coefficient of determination: 1 is perfect prediction
print('Coefficient of determination: %.2f' % r2_score(y_test, y_pred))
# Out:
# Mean squared error: 0.00
# Coefficient of determination: 1.00

# %%
# Visualize pred vs true-labels
plt.plot(np.arange(0, 100), y_pred[:100], 'r^', np.arange(0, 100), y_test[:100], 'go')
plt.title('Visualize predicts and true labels')
plt.xlabel('X label')
plt.ylabel('Y label')
plt.show()
