# %% [markdown]
# <a href="https://colab.research.google.com/github/tuananh11052000/CS114.K21/blob/master/detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("1.jpg", cv2.IMREAD_GRAYSCALE)
cv2_imshow(img);

# %%
import cv2

IMG_PATH = '1.jpg'
x = 0
y = 2*x
# read image
img = cv2.imread(IMG_PATH, cv2.IMREAD_GRAYSCALE)
heigh, width = img.shape
print(width);
ratio = heigh/width;
new_width = 300;
new_heigh = int(new_width * ratio);
img_resize = cv2.resize(img, (new_width, new_heigh))
cv2_imshow(img_resize)
detect = 0
img_crop = img[0:100, 0:200, :]
cv2_imshow(img_crop)
# crop_name = 'girl_xinh_2_crop.jpg'
# print(crop_name, img_crop.shape)

# cv2.imwrite(crop_name, img_crop)
# print('Done')
# Out:
# 960
# <PIL.Image.Image image mode=L size=300x570 at 0x7F255C7EBB70>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-dc9c709b4748> in <module>()
#      14 cv2_imshow(img_resize)
#      15 detect = 0
# ---> 16 img_crop = img[0:100, 0:200, :]
#      17 cv2_imshow(img_crop)
#      18 # crop_name = 'girl_xinh_2_crop.jpg'
#
# IndexError: too many indices for array
