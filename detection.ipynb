# %% [markdown]
# <a href="https://colab.research.google.com/github/tuananh11052000/CS114.K21/blob/master/detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("1.jpg", cv2.IMREAD_GRAYSCALE)

# %%
import cv2

IMG_PATH = '1.jpg'
x = 0
y = 2*x
# read image
img = cv2.imread(IMG_PATH, cv2.IMREAD_GRAYSCALE)
heigh, width = img.shape
print(width);
ratio = heigh/width;
new_width = 300;
new_heigh = int(new_width * ratio);
img_resize = cv2.resize(img, (new_width, new_heigh))
cv2_imshow(img_resize)
detect = 0
img_crop = img_resize[0:200, 100:300]
x = 0
while(x + 100< new_heigh):
  y = 0
  while(y + 50< new_width):
    wd = img_resize[x:x+256, y:y+128]
    wd = cv2.resize(wd, (64, 128))
    cv2_imshow(wd)
    print(wd.shape)
    print("___________")
    y = y + 50
  x = x +50
# Out:
# 960
# <PIL.Image.Image image mode=L size=300x570 at 0x7F480B2A5EF0>
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5F98>
# (128, 64)
# ___________
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5EF0>
# (128, 64)
# ___________
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5F98>
# (128, 64)
# ___________
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5FD0>
# (128, 64)
# ___________
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5EF0>
# (128, 64)
# ___________
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5FD0>
# (128, 64)
# ___________
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5F98>
# (128, 64)
# ___________
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5F60>
# (128, 64)
# ___________
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5F60>
# (128, 64)
# ___________
# <PIL.Image.Image image mode=L size=64x128 at 0x7F480B2A5F60>
# (128, 64)
# ___________
# ...
